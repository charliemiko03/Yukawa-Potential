# %%
# solver for Yukawa potential
# central field potential - use radial schrodinger eqn

# %%
import matplotlib.pyplot as plt           # from hydrogen.py
import numpy as np                        # from hydrogen.py
from math import *                        # for exponential
from scipy.constants import e, hbar, m_p  # for numerical values of q_e, hbar, m_p
from jwanglibs import rootfinder as rtf   # from hydrogen.py

# %%
def V_eff(r):                                                  # effective potential
    '''
    from hydrogen.py
    return L*(L+1)/(2*m*r**2) - 1/(4*pi*)/r                    # centrifugal + coulomb
    '''
    return hbar**2*L*(L+1)/(2*m*r**2) - V0*np.exp(-lamda*r)/r  # centrifugal + yukawa

# %%
def f(r):                            # Sch eqn in Numerov form
    return 2*m*(E-V_eff(r))/hbar**2  # rearrange radial Sch eqn

# %%
def numerov(f, u, n, x, h):     # Numerov integrator for $u''+f(x)u=0$
    nodes, c = 0, h**2/12.       # given $[u_0,u_1]$, return $[u_0,u_1,...,u_{n+1}]$
    f0, f1 = 0., f(x+h)
    for i in range(n):
        x += h
        f2 = f(x+h)             # Numerov method below, 
        u.append((2*(1-5*c*f1)*u[i+1] - (1+c*f0)*u[i])/(1+c*f2))  
        f0, f1 = f1, f2
        if u[-1]*u[-2] < 0.0:
            nodes += 1
    return u, nodes             # return u, nodes

# %%
def shoot(En):
    global E                    # E needed in f(r)
    E, c, xm = En, (h**2)/6., xL + M*h
    wfup, nup = numerov(f, [0,.1], M, xL, h)
    wfdn, ndn = numerov(f, [0,.1], N-M, xR, -h)     # $f'$ from 
    dup = ((1+c*f(xm+h))*wfup[-1] - (1+c*f(xm-h))*wfup[-3])/(h+h)
    ddn = ((1+c*f(xm+h))*wfdn[-3] - (1+c*f(xm-h))*wfdn[-1])/(h+h)
    return dup*wfdn[-2] - wfup[-2]*ddn

# %%
xL, xR, N = 10**(-5), 15., 2200  # limits, interval
m, hbar, V0 =  m_p, hbar, e**2   # constants
lamda = 10**(15)                 # yukawa interaction range
h = (xR-xL)/N                    # step size
Lmax, EL = 4, []                 # define max L, blank L array
M = 100                          # M = matching point

# %%
Estart, dE = -.5/np.arange(1, Lmax+1)**2-.1, 0.001      # $\sim -1/2n^2$
for L in range(Lmax):
    n, E1, Ea = L+1, Estart[L], []
    while (E1 < -4*dE):             # sweep E range for each L
        E1 += dE
        if (shoot(E1)*shoot(E1 + dE) > 0):
            continue
        E = rtf.bisect(shoot, E1, E1 + dE, 1.e-8)
        Ea.append(E)
        wfup, nup = numerov(f, [0,.1], M-1, xL, h)      # calc wf
        wfdn, ndn = numerov(f, [0,.1], N-M-1, xR, -h)
        psix = np.concatenate((wfup[:-1], wfdn[::-1]))
        psix[M:] *= wfup[-1]/wfdn[-1]                   # match
        print ('nodes = %i, n = %i,l = %i, E = %.8e' %(nup+ndn, n, L, E))
        n += 1
    EL.append(Ea)
# Out:
# /var/folders/0g/j1m3j1kj205g8kh8b2z5kdcm0000gn/T/ipykernel_33822/2709469739.py:9: RuntimeWarning: overflow encountered in scalar multiply
#   if u[-1]*u[-2] < 0.0:
# /var/folders/0g/j1m3j1kj205g8kh8b2z5kdcm0000gn/T/ipykernel_33822/2709469739.py:7: RuntimeWarning: overflow encountered in scalar multiply
#   u.append((2*(1-5*c*f1)*u[i+1] - (1+c*f0)*u[i])/(1+c*f2))
# /var/folders/0g/j1m3j1kj205g8kh8b2z5kdcm0000gn/T/ipykernel_33822/2709469739.py:7: RuntimeWarning: invalid value encountered in scalar subtract
#   u.append((2*(1-5*c*f1)*u[i+1] - (1+c*f0)*u[i])/(1+c*f2))
# nodes = 375, n = 1,l = 0, E = -5.99000000e-01
# nodes = 375, n = 2,l = 0, E = -5.98000000e-01
# nodes = 375, n = 3,l = 0, E = -5.97000000e-01
# nodes = 375, n = 4,l = 0, E = -5.96000000e-01
# nodes = 375, n = 5,l = 0, E = -5.95000000e-01
# nodes = 375, n = 6,l = 0, E = -5.94000000e-01
# nodes = 375, n = 7,l = 0, E = -5.93000000e-01
# nodes = 375, n = 8,l = 0, E = -5.92000000e-01
# nodes = 375, n = 9,l = 0, E = -5.91000000e-01
# nodes = 375, n = 10,l = 0, E = -5.90000000e-01
# nodes = 375, n = 11,l = 0, E = -5.89000000e-01
# nodes = 375, n = 12,l = 0, E = -5.88000000e-01
# nodes = 375, n = 13,l = 0, E = -5.87000000e-01
# nodes = 375, n = 14,l = 0, E = -5.86000000e-01
# nodes = 375, n = 15,l = 0, E = -5.85000000e-01
# nodes = 375, n = 16,l = 0, E = -5.84000000e-01
# nodes = 375, n = 17,l = 0, E = -5.83000000e-01
# nodes = 375, n = 18,l = 0, E = -5.82000000e-01
# nodes = 375, n = 19,l = 0, E = -5.81000000e-01
# nodes = 375, n = 20,l = 0, E = -5.80000000e-01
# nodes = 375, n = 21,l = 0, E = -5.79000000e-01
# nodes = 375, n = 22,l = 0, E = -5.78000000e-01
# nodes = 375, n = 23,l = 0, E = -5.77000000e-01
# nodes = 375, n = 24,l = 0, E = -5.76000000e-01
# nodes = 375, n = 25,l = 0, E = -5.75000000e-01
# nodes = 375, n = 26,l = 0, E = -5.74000000e-01
# nodes = 375, n = 27,l = 0, E = -5.73000000e-01
# nodes = 375, n = 28,l = 0, E = -5.72000000e-01
# nodes = 375, n = 29,l = 0, E = -5.71000000e-01
# nodes = 375, n = 30,l = 0, E = -5.70000000e-01
# nodes = 375, n = 31,l = 0, E = -5.69000000e-01
# nodes = 375, n = 32,l = 0, E = -5.68000000e-01
# nodes = 375, n = 33,l = 0, E = -5.67000000e-01
# nodes = 375, n = 34,l = 0, E = -5.66000000e-01
# nodes = 375, n = 35,l = 0, E = -5.65000000e-01
# nodes = 375, n = 36,l = 0, E = -5.64000000e-01
# nodes = 375, n = 37,l = 0, E = -5.63000000e-01
# nodes = 375, n = 38,l = 0, E = -5.62000000e-01
# nodes = 375, n = 180,l = 0, E = -4.20000000e-01
# nodes = 375, n = 181,l = 0, E = -4.19000000e-01
# nodes = 375, n = 182,l = 0, E = -4.18000000e-01
# nodes = 375, n = 183,l = 0, E = -4.17000000e-01
# nodes = 375, n = 184,l = 0, E = -4.16000000e-01
# nodes = 375, n = 185,l = 0, E = -4.15000000e-01
# nodes = 375, n = 186,l = 0, E = -4.14000000e-01
# nodes = 375, n = 187,l = 0, E = -4.13000000e-01
# nodes = 375, n = 188,l = 0, E = -4.12000000e-01
# nodes = 375, n = 189,l = 0, E = -4.11000000e-01
# nodes = 375, n = 190,l = 0, E = -4.10000000e-01
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[27], line 8
#       6 if (shoot(E1)*shoot(E1 + dE) > 0):
#       7     continue
# ----> 8 E = rtf.bisect(shoot, E1, E1 + dE, 1.e-8)
#       9 Ea.append(E)
#      10 wfup, nup = numerov(f, [0,.1], M-1, xL, h)      # calc wf
#
# File ~/Code/jwanglibs/src/jwanglibs/rootfinder.py:17, in bisect(f, a, b, eps)
#      15 while (True):
#      16     xmid = 0.5*(a+b)
# ---> 17     fmid = f(xmid)
#      18     if (fa*fmid > 0.0):         # root in [xmid, b]
#      19         a, fa = xmid, fmid      # set a=xmid and save a function call
#
# Cell In[21], line 5, in shoot(En)
#       3 E, c, xm = En, (h**2)/6., xL + M*h
#       4 wfup, nup = numerov(f, [0,.1], M, xL, h)
# ----> 5 wfdn, ndn = numerov(f, [0,.1], N-M, xR, -h)     # $f'$ from
#       6 dup = ((1+c*f(xm+h))*wfup[-1] - (1+c*f(xm-h))*wfup[-3])/(h+h)
#       7 ddn = ((1+c*f(xm+h))*wfdn[-3] - (1+c*f(xm-h))*wfdn[-1])/(h+h)
#
# Cell In[20], line 6, in numerov(f, u, n, x, h)
#       4 for i in range(n):
#       5     x += h
# ----> 6     f2 = f(x+h)             # Numerov method below,
#       7     u.append((2*(1-5*c*f1)*u[i+1] - (1+c*f0)*u[i])/(1+c*f2))
#       8     f0, f1 = f1, f2
#
# Cell In[19], line 2, in f(r)
#       1 def f(r):                            # Sch eqn in Numerov form
# ----> 2     return 2*m*(E-V_eff(r))/hbar**2
#
# Cell In[18], line 6, in V_eff(r)
#       1 def V_eff(r):                                                  # effective potential
#       2     '''
#       3     from hydrogen.py
#       4     return L*(L+1)/(2*m*r**2) - 1/(4*pi*)/r                    # centrifugal + coulomb
#       5     '''
# ----> 6     return hbar**2*L*(L+1)/(2*m*r**2) - V0*np.exp(-lamda*r)/r
#
# KeyboardInterrupt:

# %%
plt.figure()                        # plot energy levels
for L in range(Lmax):
    for i in range(len(EL[L])):
        plt.plot([L-.3, L+.3], [EL[L][i]]*2, 'k-')
    plt.xlabel('$l$'), plt.ylabel('$E$')
    plt.ylim(-.51, 0), plt.xticks(range(Lmax))
plt.show()
